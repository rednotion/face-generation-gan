# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    image_transformations = transforms.Compose([
        transforms.Resize(image_size),
        transforms.CenterCrop(image_size),
        transforms.ToTensor()
    ])
    
    dataset = datasets.ImageFolder(
        root=data_dir,
        transform=image_transformations
    )
    
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max-min) + min
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9373)
# Max:  tensor(0.9922)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv_layer(in_channels, out_channels, kernel, stride=2, padding=1, batch_norm=True):
    """
    Helper function to define a conv2d layer, with optional batch norm
    """
    layers = [
        nn.Conv2d(in_channels, out_channels, kernel, stride, padding, bias=False)
    ]
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)


class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        self.conv_dim = conv_dim
        
        self.conv1 = conv_layer(3, conv_dim, 4, batch_norm=False) # 32 to 16
        self.conv2 = conv_layer(conv_dim, conv_dim*2, 4) # 16 to 8
        self.conv3 = conv_layer(conv_dim*2, conv_dim*4, 4) # 8 to 4
        
        self.fc = nn.Linear(conv_dim*4*4*4, 1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        
        # flatten
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def conv_transpose(in_channels, out_channels, kernel, stride=2, padding=1, batch_norm=True):
    layers = [
        nn.ConvTranspose2d(in_channels, out_channels, kernel, stride, padding, bias=False)
    ]
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layers)


class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        self.conv_dim = conv_dim

        self.fc = nn.Linear(z_size, conv_dim*4*4*4) # 4x4
        self.convt1 = conv_transpose(conv_dim*4, conv_dim*2, 4) # 8x8
        self.convt2 = conv_transpose(conv_dim*2, conv_dim, 4) # 16x16
        self.convt3 = conv_transpose(conv_dim, 3, 4, batch_norm=False) # 32x32

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        x = self.fc(x)
        
        # reshape
        x = x.view(-1, self.conv_dim*4, 4, 4)
        
        # conv
        x = F.leaky_relu(self.convt1(x), 0.2)
        x = F.leaky_relu(self.convt2(x), 0.2)
        x = F.tanh(self.convt3(x))
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:  # BatchNorm Layer's weight is not a matrix; only normal distribution applies.
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 128

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=4096, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=128, out_features=4096, bias=True)
#   (convt1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convt2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convt3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size)*0.9 if smooth else torch.ones(batch_size)

    # move labels to GPU if available     
    if torch.cuda.is_available():
        labels = labels.cuda()
        
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size).cuda() if torch.cuda.is_available() else torch.zeros(batch_size)
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

d_conv_dim = 64
g_conv_dim = 64
z_size = 128 

D, G = build_network(d_conv_dim, g_conv_dim, z_size)

lr = 0.0002
beta1 = 0.5
beta2 = 0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=4096, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=128, out_features=4096, bias=True)
#   (convt1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convt2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convt3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            # 1. Train the discriminator on real and fake images
            
            d_optimizer.zero_grad()
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()

            if torch.cuda.is_available():
                real_images = real_images.cuda()
                z = z.cuda()

            fake_images = G(z)
            D_real = D(real_images)
            D_fake = D(fake_images)
            d_real_loss = real_loss(D_real, smooth=True)
            d_fake_loss = fake_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            
            g_optimizer.zero_grad()

            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if torch.cuda.is_available():
                z = z.cuda()
            
            fake_images = G(z)
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # real loss to flip labels
            
            g_loss.backward()
            g_optimizer.step()

            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
import signal

from contextlib import contextmanager

import requests


DELAY = INTERVAL = 4 * 60  # interval time in seconds
MIN_DELAY = MIN_INTERVAL = 2 * 60
KEEPALIVE_URL = "https://nebula.udacity.com/api/v1/remote/keep-alive"
TOKEN_URL = "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token"
TOKEN_HEADERS = {"Metadata-Flavor":"Google"}


def _request_handler(headers):
    def _handler(signum, frame):
        requests.request("POST", KEEPALIVE_URL, headers=headers)
    return _handler


@contextmanager
def active_session(delay=DELAY, interval=INTERVAL):
    """
    Example:

    from workspace_utils import active session

    with active_session():
        # do long-running work here
    """
    token = requests.request("GET", TOKEN_URL, headers=TOKEN_HEADERS).text
    headers = {'Authorization': "STAR " + token}
    delay = max(delay, MIN_DELAY)
    interval = max(interval, MIN_INTERVAL)
    original_handler = signal.getsignal(signal.SIGALRM)
    try:
        signal.signal(signal.SIGALRM, _request_handler(headers))
        signal.setitimer(signal.ITIMER_REAL, delay, interval)
        yield
    finally:
        signal.signal(signal.SIGALRM, original_handler)
        signal.setitimer(signal.ITIMER_REAL, 0)


def keep_awake(iterable, delay=DELAY, interval=INTERVAL):
    """
    Example:

    from workspace_utils import keep_awake

    for i in keep_awake(range(5)):
        # do iteration with lots of work here
    """
    with active_session(delay, interval): yield from iterable

# %%
# set number of epochs 
n_epochs = 100


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
with active_session():
    losses = train(D, G, n_epochs=n_epochs, print_every=1000)
# Out:
# Epoch [    1/  100] | d_loss: 2.0103 | g_loss: 1.4416
# Epoch [    1/  100] | d_loss: 1.0274 | g_loss: 1.6203
# Epoch [    1/  100] | d_loss: 0.8575 | g_loss: 1.6540
# Epoch [    2/  100] | d_loss: 0.7386 | g_loss: 2.0744
# Epoch [    2/  100] | d_loss: 1.1229 | g_loss: 1.1451
# Epoch [    2/  100] | d_loss: 0.9279 | g_loss: 1.4483
# Epoch [    3/  100] | d_loss: 1.0203 | g_loss: 2.3284
# Epoch [    3/  100] | d_loss: 0.9386 | g_loss: 3.0048
# Epoch [    3/  100] | d_loss: 0.6212 | g_loss: 2.1093
# Epoch [    4/  100] | d_loss: 0.9902 | g_loss: 2.2271
# Epoch [    4/  100] | d_loss: 0.9030 | g_loss: 0.5797
# Epoch [    4/  100] | d_loss: 0.9049 | g_loss: 3.0359
# Epoch [    5/  100] | d_loss: 0.8750 | g_loss: 2.4432
# Epoch [    5/  100] | d_loss: 0.8031 | g_loss: 1.9620
# Epoch [    5/  100] | d_loss: 0.6793 | g_loss: 3.1033
# Epoch [    6/  100] | d_loss: 0.7471 | g_loss: 1.8865
# Epoch [    6/  100] | d_loss: 0.7905 | g_loss: 2.3995
# Epoch [    6/  100] | d_loss: 0.7315 | g_loss: 1.9898
# Epoch [    7/  100] | d_loss: 1.0110 | g_loss: 3.6306
# Epoch [    7/  100] | d_loss: 0.5321 | g_loss: 2.5002
# Epoch [    7/  100] | d_loss: 0.5573 | g_loss: 1.9809
# Epoch [    8/  100] | d_loss: 0.7289 | g_loss: 3.6198
# Epoch [    8/  100] | d_loss: 0.9082 | g_loss: 2.4219
# Epoch [    8/  100] | d_loss: 0.5884 | g_loss: 1.9554
# Epoch [    9/  100] | d_loss: 1.1368 | g_loss: 3.5749
# Epoch [    9/  100] | d_loss: 0.5534 | g_loss: 3.1875
# Epoch [    9/  100] | d_loss: 0.7899 | g_loss: 2.4642
# Epoch [   10/  100] | d_loss: 0.6522 | g_loss: 2.6108
# Epoch [   10/  100] | d_loss: 0.5786 | g_loss: 2.4136
# Epoch [   10/  100] | d_loss: 0.5937 | g_loss: 3.0400
# Epoch [   11/  100] | d_loss: 0.6580 | g_loss: 2.5777
# Epoch [   11/  100] | d_loss: 0.8446 | g_loss: 2.1835
# Epoch [   11/  100] | d_loss: 0.8481 | g_loss: 3.5862
# Epoch [   12/  100] | d_loss: 0.8069 | g_loss: 3.2498
# Epoch [   12/  100] | d_loss: 1.2673 | g_loss: 1.5047
# Epoch [   12/  100] | d_loss: 1.2818 | g_loss: 5.4499
# Epoch [   13/  100] | d_loss: 0.5179 | g_loss: 3.8544
# Epoch [   13/  100] | d_loss: 0.4953 | g_loss: 3.9671
# Epoch [   13/  100] | d_loss: 0.5112 | g_loss: 3.6930
# Epoch [   14/  100] | d_loss: 1.3858 | g_loss: 3.6805
# Epoch [   14/  100] | d_loss: 0.5031 | g_loss: 3.2825
# Epoch [   14/  100] | d_loss: 0.4991 | g_loss: 3.2522
# Epoch [   15/  100] | d_loss: 1.1396 | g_loss: 1.0860
# Epoch [   15/  100] | d_loss: 0.5127 | g_loss: 3.5327
# Epoch [   15/  100] | d_loss: 0.6729 | g_loss: 2.3917
# Epoch [   16/  100] | d_loss: 0.6825 | g_loss: 2.3681
# Epoch [   16/  100] | d_loss: 0.8021 | g_loss: 2.7609
# Epoch [   16/  100] | d_loss: 0.4923 | g_loss: 2.5957
# Epoch [   17/  100] | d_loss: 1.0090 | g_loss: 3.2822
# Epoch [   17/  100] | d_loss: 0.4502 | g_loss: 3.6962
# Epoch [   17/  100] | d_loss: 0.4282 | g_loss: 2.9542
# Epoch [   18/  100] | d_loss: 0.7889 | g_loss: 4.4766
# Epoch [   18/  100] | d_loss: 0.4952 | g_loss: 2.8490
# Epoch [   18/  100] | d_loss: 0.5234 | g_loss: 1.9083
# Epoch [   19/  100] | d_loss: 0.5312 | g_loss: 3.3504
# Epoch [   19/  100] | d_loss: 0.6038 | g_loss: 3.1478
# Epoch [   19/  100] | d_loss: 0.7848 | g_loss: 2.5063
# Epoch [   20/  100] | d_loss: 0.4482 | g_loss: 3.2486
# Epoch [   20/  100] | d_loss: 0.4901 | g_loss: 3.4748
# Epoch [   20/  100] | d_loss: 0.7115 | g_loss: 4.6404
# Epoch [   21/  100] | d_loss: 0.4560 | g_loss: 2.5245
# Epoch [   21/  100] | d_loss: 0.4305 | g_loss: 3.0971
# Epoch [   21/  100] | d_loss: 0.4475 | g_loss: 4.2076
# Epoch [   22/  100] | d_loss: 0.4313 | g_loss: 4.2782
# Epoch [   22/  100] | d_loss: 0.6552 | g_loss: 3.9235
# Epoch [   22/  100] | d_loss: 0.6929 | g_loss: 3.0423
# Epoch [   23/  100] | d_loss: 0.4003 | g_loss: 4.1355
# Epoch [   23/  100] | d_loss: 0.5725 | g_loss: 3.6834
# Epoch [   23/  100] | d_loss: 0.4987 | g_loss: 3.3427
# Epoch [   24/  100] | d_loss: 0.4852 | g_loss: 4.5266
# Epoch [   24/  100] | d_loss: 0.4168 | g_loss: 4.4147
# Epoch [   24/  100] | d_loss: 0.8413 | g_loss: 3.6940
# Epoch [   25/  100] | d_loss: 0.6502 | g_loss: 1.5799
# Epoch [   25/  100] | d_loss: 0.6843 | g_loss: 3.8019
# Epoch [   25/  100] | d_loss: 0.4084 | g_loss: 4.3516
# Epoch [   26/  100] | d_loss: 0.9751 | g_loss: 3.3501
# Epoch [   26/  100] | d_loss: 0.6595 | g_loss: 3.3244
# Epoch [   26/  100] | d_loss: 0.4514 | g_loss: 4.7532
# Epoch [   27/  100] | d_loss: 0.6829 | g_loss: 2.8109
# Epoch [   27/  100] | d_loss: 0.4824 | g_loss: 2.9244
# Epoch [   27/  100] | d_loss: 0.4333 | g_loss: 4.2092
# Epoch [   28/  100] | d_loss: 0.6165 | g_loss: 2.3224
# Epoch [   28/  100] | d_loss: 0.5742 | g_loss: 3.6211
# Epoch [   28/  100] | d_loss: 0.4836 | g_loss: 3.3621
# Epoch [   29/  100] | d_loss: 0.4522 | g_loss: 3.5203
# Epoch [   29/  100] | d_loss: 0.4185 | g_loss: 4.1518
# Epoch [   30/  100] | d_loss: 0.5009 | g_loss: 4.2128
# Epoch [   31/  100] | d_loss: 0.5955 | g_loss: 3.7827
# Epoch [   31/  100] | d_loss: 0.8339 | g_loss: 2.4942
# Epoch [   31/  100] | d_loss: 0.4190 | g_loss: 5.2700
# Epoch [   32/  100] | d_loss: 0.6444 | g_loss: 4.2902
# Epoch [   32/  100] | d_loss: 0.4343 | g_loss: 4.5865
# Epoch [   32/  100] | d_loss: 0.6281 | g_loss: 3.4745
# Epoch [   33/  100] | d_loss: 0.4269 | g_loss: 4.7341
# Epoch [   33/  100] | d_loss: 0.5321 | g_loss: 4.1857
# Epoch [   33/  100] | d_loss: 0.4855 | g_loss: 3.2880
# Epoch [   34/  100] | d_loss: 0.3871 | g_loss: 4.6046
# Epoch [   34/  100] | d_loss: 0.4899 | g_loss: 4.4564
# Epoch [   34/  100] | d_loss: 0.4054 | g_loss: 4.9083
# Epoch [   35/  100] | d_loss: 0.5881 | g_loss: 4.7050
# Epoch [   35/  100] | d_loss: 0.4751 | g_loss: 2.8817
# Epoch [   35/  100] | d_loss: 0.4241 | g_loss: 3.7092
# Epoch [   36/  100] | d_loss: 0.4432 | g_loss: 3.3924
# Epoch [   36/  100] | d_loss: 0.4145 | g_loss: 4.4808
# Epoch [   36/  100] | d_loss: 0.4016 | g_loss: 3.4428
# Epoch [   37/  100] | d_loss: 0.4066 | g_loss: 5.5922
# Epoch [   37/  100] | d_loss: 0.4049 | g_loss: 4.8615
# Epoch [   37/  100] | d_loss: 0.3947 | g_loss: 5.4488
# Epoch [   38/  100] | d_loss: 0.4736 | g_loss: 3.4988
# Epoch [   38/  100] | d_loss: 0.4430 | g_loss: 3.8448
# Epoch [   38/  100] | d_loss: 0.4245 | g_loss: 4.6422
# Epoch [   39/  100] | d_loss: 0.4252 | g_loss: 5.4830
# Epoch [   39/  100] | d_loss: 0.4188 | g_loss: 4.9848
# Epoch [   39/  100] | d_loss: 0.4014 | g_loss: 4.1015
# Epoch [   40/  100] | d_loss: 0.7454 | g_loss: 3.1132
# Epoch [   40/  100] | d_loss: 0.3945 | g_loss: 3.8448
# Epoch [   40/  100] | d_loss: 0.3906 | g_loss: 3.9508
# Epoch [   41/  100] | d_loss: 0.9991 | g_loss: 5.2248
# Epoch [   41/  100] | d_loss: 0.3969 | g_loss: 4.6374
# Epoch [   41/  100] | d_loss: 0.4473 | g_loss: 3.1260
# Epoch [   42/  100] | d_loss: 0.3679 | g_loss: 5.2215
# Epoch [   42/  100] | d_loss: 0.3729 | g_loss: 5.5685
# Epoch [   42/  100] | d_loss: 0.6343 | g_loss: 3.0210
# Epoch [   43/  100] | d_loss: 0.4306 | g_loss: 3.6906
# Epoch [   43/  100] | d_loss: 0.4889 | g_loss: 3.1640
# Epoch [   43/  100] | d_loss: 0.4657 | g_loss: 4.1755
# Epoch [   44/  100] | d_loss: 0.5348 | g_loss: 3.7491
# Epoch [   44/  100] | d_loss: 0.4671 | g_loss: 5.5190
# Epoch [   44/  100] | d_loss: 0.5308 | g_loss: 3.9072
# Epoch [   45/  100] | d_loss: 0.3780 | g_loss: 4.2536
# Epoch [   45/  100] | d_loss: 0.6055 | g_loss: 2.5113
# Epoch [   45/  100] | d_loss: 0.4021 | g_loss: 4.0901
# Epoch [   46/  100] | d_loss: 0.4495 | g_loss: 3.8599
# Epoch [   46/  100] | d_loss: 0.6155 | g_loss: 3.9497
# Epoch [   46/  100] | d_loss: 0.4395 | g_loss: 3.7139
# Epoch [   47/  100] | d_loss: 0.5415 | g_loss: 4.2674
# Epoch [   47/  100] | d_loss: 0.3969 | g_loss: 4.7204
# Epoch [   47/  100] | d_loss: 0.4077 | g_loss: 4.5545
# Epoch [   48/  100] | d_loss: 0.4751 | g_loss: 4.8973
# Epoch [   48/  100] | d_loss: 0.4535 | g_loss: 5.2028
# Epoch [   48/  100] | d_loss: 0.3758 | g_loss: 3.9812
# Epoch [   49/  100] | d_loss: 0.4472 | g_loss: 4.5462
# Epoch [   49/  100] | d_loss: 0.3916 | g_loss: 4.1817
# Epoch [   49/  100] | d_loss: 0.4485 | g_loss: 4.9275
# Epoch [   50/  100] | d_loss: 1.1339 | g_loss: 4.1356
# Epoch [   50/  100] | d_loss: 0.3817 | g_loss: 5.4958
# Epoch [   50/  100] | d_loss: 0.4032 | g_loss: 5.4755
# Epoch [   51/  100] | d_loss: 0.4400 | g_loss: 4.7822
# Epoch [   51/  100] | d_loss: 0.4037 | g_loss: 5.2710
# Epoch [   51/  100] | d_loss: 0.4095 | g_loss: 4.5574
# Epoch [   52/  100] | d_loss: 0.4105 | g_loss: 3.7206
# Epoch [   52/  100] | d_loss: 0.4177 | g_loss: 4.1610
# Epoch [   52/  100] | d_loss: 0.4455 | g_loss: 4.6805
# Epoch [   53/  100] | d_loss: 0.3643 | g_loss: 5.3847
# Epoch [   53/  100] | d_loss: 0.4091 | g_loss: 4.4996
# Epoch [   53/  100] | d_loss: 0.3633 | g_loss: 4.7274
# Epoch [   54/  100] | d_loss: 0.6543 | g_loss: 4.1530
# Epoch [   54/  100] | d_loss: 0.3942 | g_loss: 5.4957
# Epoch [   54/  100] | d_loss: 0.4279 | g_loss: 4.5865
# Epoch [   55/  100] | d_loss: 1.1834 | g_loss: 4.6075
# Epoch [   55/  100] | d_loss: 0.3706 | g_loss: 5.3613
# Epoch [   55/  100] | d_loss: 0.4126 | g_loss: 3.9543
# Epoch [   56/  100] | d_loss: 0.5029 | g_loss: 2.8719
# Epoch [   56/  100] | d_loss: 0.4145 | g_loss: 4.0884
# Epoch [   56/  100] | d_loss: 0.4024 | g_loss: 3.1773
# Epoch [   57/  100] | d_loss: 0.4096 | g_loss: 6.0178
# Epoch [   57/  100] | d_loss: 0.4280 | g_loss: 4.0655
# Epoch [   57/  100] | d_loss: 0.3627 | g_loss: 5.2955
# Epoch [   58/  100] | d_loss: 0.4121 | g_loss: 4.8542
# Epoch [   58/  100] | d_loss: 0.4775 | g_loss: 5.2165
# Epoch [   58/  100] | d_loss: 0.3976 | g_loss: 3.2604
# Epoch [   59/  100] | d_loss: 0.3757 | g_loss: 4.4570
# Epoch [   59/  100] | d_loss: 0.3881 | g_loss: 5.3541
# Epoch [   59/  100] | d_loss: 0.5287 | g_loss: 4.1341
# Epoch [   60/  100] | d_loss: 0.3860 | g_loss: 4.3272
# Epoch [   60/  100] | d_loss: 0.4015 | g_loss: 5.0771
# Epoch [   60/  100] | d_loss: 0.6191 | g_loss: 3.9214
# Epoch [   61/  100] | d_loss: 0.4074 | g_loss: 5.0657
# Epoch [   61/  100] | d_loss: 0.4075 | g_loss: 3.5233
# Epoch [   61/  100] | d_loss: 0.3979 | g_loss: 3.9893
# Epoch [   62/  100] | d_loss: 0.3602 | g_loss: 5.6282
# Epoch [   62/  100] | d_loss: 0.3774 | g_loss: 4.7372
# Epoch [   62/  100] | d_loss: 0.3975 | g_loss: 4.6971
# Epoch [   63/  100] | d_loss: 0.4680 | g_loss: 3.4013
# Epoch [   63/  100] | d_loss: 1.0572 | g_loss: 4.5936
# Epoch [   63/  100] | d_loss: 0.3940 | g_loss: 4.1696
# Epoch [   64/  100] | d_loss: 0.4136 | g_loss: 3.5714
# Epoch [   64/  100] | d_loss: 0.3882 | g_loss: 3.3285
# Epoch [   64/  100] | d_loss: 0.3590 | g_loss: 5.8297
# Epoch [   65/  100] | d_loss: 0.4216 | g_loss: 4.0652
# Epoch [   65/  100] | d_loss: 0.3891 | g_loss: 5.9417
# Epoch [   65/  100] | d_loss: 0.4471 | g_loss: 4.6617
# Epoch [   66/  100] | d_loss: 0.4021 | g_loss: 3.6113
# Epoch [   66/  100] | d_loss: 0.3690 | g_loss: 4.4424
# Epoch [   66/  100] | d_loss: 0.3992 | g_loss: 5.0710
# Epoch [   67/  100] | d_loss: 0.4425 | g_loss: 5.0961
# Epoch [   67/  100] | d_loss: 0.3676 | g_loss: 5.0803
# Epoch [   67/  100] | d_loss: 0.4234 | g_loss: 4.4585
# Epoch [   68/  100] | d_loss: 0.4606 | g_loss: 4.5719
# Epoch [   68/  100] | d_loss: 0.4089 | g_loss: 3.9425
# Epoch [   68/  100] | d_loss: 0.3554 | g_loss: 6.2862
# Epoch [   69/  100] | d_loss: 0.3891 | g_loss: 4.8954
# Epoch [   69/  100] | d_loss: 0.3695 | g_loss: 5.0295
# Epoch [   69/  100] | d_loss: 0.3637 | g_loss: 5.8206
# Epoch [   70/  100] | d_loss: 0.9976 | g_loss: 4.8455
# Epoch [   70/  100] | d_loss: 0.3693 | g_loss: 3.8699
# Epoch [   70/  100] | d_loss: 0.3993 | g_loss: 4.7480
# Epoch [   71/  100] | d_loss: 0.3776 | g_loss: 5.2642
# Epoch [   71/  100] | d_loss: 0.4465 | g_loss: 3.9138
# Epoch [   71/  100] | d_loss: 0.3894 | g_loss: 5.0798
# Epoch [   72/  100] | d_loss: 0.3607 | g_loss: 4.9840
# Epoch [   72/  100] | d_loss: 0.3833 | g_loss: 4.7675
# Epoch [   72/  100] | d_loss: 0.3727 | g_loss: 5.3304
# Epoch [   73/  100] | d_loss: 0.3702 | g_loss: 5.2009
# Epoch [   73/  100] | d_loss: 0.7029 | g_loss: 2.9282
# Epoch [   73/  100] | d_loss: 0.3869 | g_loss: 5.2330
# Epoch [   74/  100] | d_loss: 0.7130 | g_loss: 4.5079
# Epoch [   74/  100] | d_loss: 0.4211 | g_loss: 4.7673
# Epoch [   74/  100] | d_loss: 0.3914 | g_loss: 4.4219
# Epoch [   75/  100] | d_loss: 0.4164 | g_loss: 5.2061
# Epoch [   75/  100] | d_loss: 0.5151 | g_loss: 2.2861
# Epoch [   75/  100] | d_loss: 0.3932 | g_loss: 4.5716
# Epoch [   76/  100] | d_loss: 0.4328 | g_loss: 2.7020
# Epoch [   76/  100] | d_loss: 0.3997 | g_loss: 3.3528
# Epoch [   76/  100] | d_loss: 0.4303 | g_loss: 3.7465
# Epoch [   77/  100] | d_loss: 0.3781 | g_loss: 5.2897
# Epoch [   77/  100] | d_loss: 0.3854 | g_loss: 3.9518
# Epoch [   77/  100] | d_loss: 0.4054 | g_loss: 5.7904
# Epoch [   78/  100] | d_loss: 0.4339 | g_loss: 6.7715
# Epoch [   78/  100] | d_loss: 0.5502 | g_loss: 7.3461
# Epoch [   78/  100] | d_loss: 0.4950 | g_loss: 5.7544
# Epoch [   79/  100] | d_loss: 0.3745 | g_loss: 6.7891
# Epoch [   79/  100] | d_loss: 0.3782 | g_loss: 6.3535
# Epoch [   79/  100] | d_loss: 0.3781 | g_loss: 4.1894
# Epoch [   80/  100] | d_loss: 0.4679 | g_loss: 3.9949
# Epoch [   80/  100] | d_loss: 0.3746 | g_loss: 6.4390
# Epoch [   80/  100] | d_loss: 0.3894 | g_loss: 4.8433
# Epoch [   81/  100] | d_loss: 0.3907 | g_loss: 5.1743
# Epoch [   81/  100] | d_loss: 0.3689 | g_loss: 6.5490
# Epoch [   81/  100] | d_loss: 0.4657 | g_loss: 3.5754
# Epoch [   82/  100] | d_loss: 0.5630 | g_loss: 5.2149
# Epoch [   82/  100] | d_loss: 0.4046 | g_loss: 5.5574
# Epoch [   82/  100] | d_loss: 0.3894 | g_loss: 5.8525
# Epoch [   83/  100] | d_loss: 0.5078 | g_loss: 5.1928
# Epoch [   83/  100] | d_loss: 0.3994 | g_loss: 3.6603
# Epoch [   83/  100] | d_loss: 0.3878 | g_loss: 5.6104
# Epoch [   84/  100] | d_loss: 0.3983 | g_loss: 4.1222
# Epoch [   84/  100] | d_loss: 0.3579 | g_loss: 5.6833
# Epoch [   84/  100] | d_loss: 0.4028 | g_loss: 5.4811
# Epoch [   85/  100] | d_loss: 0.4181 | g_loss: 4.4967
# Epoch [   85/  100] | d_loss: 0.3601 | g_loss: 4.8923
# Epoch [   85/  100] | d_loss: 0.5913 | g_loss: 3.3837
# Epoch [   86/  100] | d_loss: 0.7956 | g_loss: 3.7312
# Epoch [   86/  100] | d_loss: 0.3719 | g_loss: 5.7051
# Epoch [   86/  100] | d_loss: 0.4097 | g_loss: 4.1462
# Epoch [   87/  100] | d_loss: 0.4628 | g_loss: 4.0218
# Epoch [   87/  100] | d_loss: 0.3564 | g_loss: 5.9397
# Epoch [   87/  100] | d_loss: 0.4007 | g_loss: 4.1627
# Epoch [   88/  100] | d_loss: 0.3576 | g_loss: 4.7339
# Epoch [   88/  100] | d_loss: 0.3825 | g_loss: 4.1947
# Epoch [   88/  100] | d_loss: 0.3825 | g_loss: 4.4274
# Epoch [   89/  100] | d_loss: 0.4179 | g_loss: 3.3923
# Epoch [   89/  100] | d_loss: 0.3658 | g_loss: 4.4541
# Epoch [   89/  100] | d_loss: 0.4335 | g_loss: 4.5697
# Epoch [   90/  100] | d_loss: 0.3782 | g_loss: 4.9638
# Epoch [   90/  100] | d_loss: 0.3638 | g_loss: 5.6863
# Epoch [   90/  100] | d_loss: 0.3670 | g_loss: 5.0795
# Epoch [   91/  100] | d_loss: 0.4003 | g_loss: 4.7230
# Epoch [   91/  100] | d_loss: 0.3670 | g_loss: 4.8557
# Epoch [   91/  100] | d_loss: 0.3739 | g_loss: 5.7869
# Epoch [   92/  100] | d_loss: 0.3692 | g_loss: 4.1923
# Epoch [   92/  100] | d_loss: 0.3705 | g_loss: 5.4242
# Epoch [   92/  100] | d_loss: 0.3651 | g_loss: 4.9130
# Epoch [   93/  100] | d_loss: 0.3904 | g_loss: 4.9364
# Epoch [   93/  100] | d_loss: 0.3614 | g_loss: 5.5353
# Epoch [   93/  100] | d_loss: 0.4291 | g_loss: 4.4103
# Epoch [   94/  100] | d_loss: 0.3957 | g_loss: 5.0309
# Epoch [   94/  100] | d_loss: 0.3803 | g_loss: 5.5323
# Epoch [   94/  100] | d_loss: 0.3714 | g_loss: 5.4500
# Epoch [   95/  100] | d_loss: 0.3952 | g_loss: 6.6142
# Epoch [   95/  100] | d_loss: 0.3636 | g_loss: 4.3984
# Epoch [   95/  100] | d_loss: 0.5432 | g_loss: 3.7071
# Epoch [   96/  100] | d_loss: 0.5502 | g_loss: 2.6286
# Epoch [   96/  100] | d_loss: 0.4599 | g_loss: 4.9460
# Epoch [   96/  100] | d_loss: 0.3752 | g_loss: 4.4248
# Epoch [   97/  100] | d_loss: 0.4084 | g_loss: 3.5935
# Epoch [   97/  100] | d_loss: 0.4033 | g_loss: 4.0804
# Epoch [   97/  100] | d_loss: 0.3859 | g_loss: 3.6712
# Epoch [   98/  100] | d_loss: 0.4269 | g_loss: 4.4462
# Epoch [   98/  100] | d_loss: 0.3569 | g_loss: 5.6079
# Epoch [   98/  100] | d_loss: 0.3736 | g_loss: 4.3840
# Epoch [   99/  100] | d_loss: 0.3641 | g_loss: 5.4522
# Epoch [   99/  100] | d_loss: 0.3775 | g_loss: 5.2233
# Epoch [   99/  100] | d_loss: 0.4747 | g_loss: 4.3384
# Epoch [  100/  100] | d_loss: 0.3691 | g_loss: 4.9752
# Epoch [  100/  100] | d_loss: 0.3671 | g_loss: 6.1421
# Epoch [  100/  100] | d_loss: 0.4126 | g_loss: 4.7228

# %%
torch.save(D.state_dict(), 'discriminator_06022020.pt')
torch.save(G.state_dict(), 'generator_06022020.pt')

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots(figsize=(12, 3))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %%
# Print some additional samples
G.eval()
fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
for ax in axes.flatten():
    z = np.random.uniform(-1, 1, size=(1, z_size))
    z = torch.from_numpy(z).float().cuda()
    test_img = G(z)
    test_img = test_img.view((3,32,32)).detach().cpu().numpy()
    test_img = np.transpose(test_img, (1, 2, 0))
    test_img = ((test_img + 1)*255 / (2)).astype(np.uint8)
    ax.imshow(test_img.reshape((32, 32, 3)))

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
# - Many of the generated faces tend to be females (with makeup), which may be a reflection of the dataset, and also the makeup might help to make the features more distinctive and thus they emerge more often
#     - The best samples tend to have **high contrast** e.g. dark hair and eyes with light skin
#     - Some of the fair skin & light hair photos don't look as good
# - The generator is able to infer and build the core features of a face, such as eyes, eyebrows, nsoe and mouth. It also performs quite well in conveying appropriate skin tones and gradients (e.g. according to highlights and shadows)
# - However, some of the generated samples still require additional work/smoothing: the core components are there (eyes lip nose) but may be placed in odd positions without a proper framing of the jaw/hair
# - Potential methods to improve the model could be
#     - Training for more epochs
#     - Creater a deeper generator
#     - Adding more data

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
